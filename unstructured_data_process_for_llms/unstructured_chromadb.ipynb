# %%
import json
from IPython.display import JSON

from unstructured_client import UnstructuredClient
from unstructured_client.models import shared
from unstructured_client.models.errors import SDKError

from unstructured.chunking.basic import chunk_elements
from unstructured.chunking.title import chunk_by_title
from unstructured.staging.base import dict_to_elements

import chromadb
# Out:
# INFO: NumExpr defaulting to 8 threads.

# %%
DLAI_API_KEY = ""
DLAI_API_URL = ""

# %%
s =  UnstructuredClient(
    api_key_auth=DLAI_API_KEY,
    server_url=DLAI_API_URL,    
)

# %%
filename = "winter-sports.epub"
with open(filename,'rb') as f:
    files = shared.Files(
        content =  f.read(),
        file_name=filename
    )
req =  shared.PartitionParameters(files=files)

# %%
res = s.general.partition(req)

# %%
res.elements
# Out:
# [{'type': 'Title',
#   'element_id': '0c6fff519d8892b1783ead469b230320',
#   'text': 'The Project Gutenberg eBook of Winter Sports in\nSwitzerland, by E. F. Benson',
#   'metadata': {'page_number': 1,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'NarrativeText',
#   'element_id': 'a704b2f040706162ec4539fe6e0bfae9',
#   'text': '\nThis ebook is for the use of anyone anywhere in the United States and\nmost other parts of the world at no cost and with almost no restrictions\nwhatsoever. You may copy it, give it away or re-use it under the terms\nof the Project Gutenberg License included with this ebook or online at\n',
#   'metadata': {'page_number': 1,
#    'languages': ['eng'],
#    'parent_id': '0c6fff519d8892b1783ead469b230320',
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'NarrativeText',
#   'element_id': '5b5eebc5d7d1c47189123b2b25b0204e',
#   'text': 'www.gutenberg.org. If you are not located\nin the United States, you’ll have to check the laws of the country where\nyou are located before using this eBook.',
#   'metadata': {'page_number': 1,
#    'languages': ['eng'],
#    'parent_id': '0c6fff519d8892b1783ead469b230320',
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '4a7aedb1f1383e75bb0ee85e359cee60',
#   'text': 'Title: Winter Sports in Switzerland',
#   'metadata': {'page_number': 1,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '395a1ca8c9a7512b4ef7910c383f02f0',
#   'text': 'Author: E. F. Benson',
#   'metadata': {'page_number': 1,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'd13cc748dfa64302f1cacc7df9eb8ce6',
#   'text': 'Illustrator: C. Fleming Williams',
#   'metadata': {'page_number': 1,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'a5254421f3a21ec28163a78d8fcc5765',
#   'text': 'Photographer: Mrs. Aubrey Le Blond',
#   'metadata': {'page_number': 1,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'e25742b8ac3c8efa7593309396dfb342',
#   'text': 'Release date: August 23, 2019 [EBook #60153]',
#   'metadata': {'page_number': 1,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'NarrativeText',
#   'element_id': 'c453eb80776907584998ce44f8b2f77a',
#   'text': 'Most recently updated: January 30, 2020',
#   'metadata': {'page_number': 1,
#    'languages': ['eng'],
#    'parent_id': 'e25742b8ac3c8efa7593309396dfb342',
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'b57efaf39e21b67232bab14763e8c43f',
#   'text': 'Language: English',
#   'metadata': {'page_number': 1,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '1917835b784d18dabafdb3d112f1f45e',
#   'text': 'Credits: Produced by Chuck Greif and the Online\nDistributed',
#   'metadata': {'page_number': 1,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'NarrativeText',
#   'element_id': '90850f1f744ee167a0f51ee12c312ab2',
#   'text': 'Proofreading Team at http://www.pgdp.net (This file was',
#   'metadata': {'page_number': 1,
#    'languages': ['eng'],
#    'parent_id': '1917835b784d18dabafdb3d112f1f45e',
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'NarrativeText',
#   'element_id': '5360779f223b6948e7c50c6ebed9cbcd',
#   'text': 'produced from images available at The Internet Archive)',
#   'metadata': {'page_number': 1,
#    'languages': ['eng'],
#    'parent_id': '1917835b784d18dabafdb3d112f1f45e',
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'UncategorizedText',
#   'element_id': '3596c4c5771a39d59f6cc657e42786d6',
#   'text': '*** START OF THE PROJECT GUTENBERG EBOOK WINTER SPORTS IN\nSWITZERLAND ***',
#   'metadata': {'page_number': 1,
#    'languages': ['eng'],
#    'parent_id': '1917835b784d18dabafdb3d112f1f45e',
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Table',
#   'element_id': '9cd0033ad07a64c1502d969fe2ccd47c',
#   'text': "Contents. List of Illustrations (In certain versions of this etext [in certain\nbrowsers] clicking on the image will bring up a larger\nversion.) (etext transcriber's note)",
#   'metadata': {'text_as_html': '<table><tr><td>Contents. List of Illustrations (In certain versions of this etext [in certain<br/>browsers] clicking on the image will bring up a larger<br/>version.) (etext transcriber&#x27;s note)</td></tr></table>',
#    'page_number': 2,
#    'languages': ['eng'],
#    'parent_id': '1917835b784d18dabafdb3d112f1f45e',
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'e1b22c3e168288282d72f5c55043859e',
#   'text': '[Image unavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'a293506132f847d3df66f9d8de03b881',
#   'text': 'THE EIGER',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '82622f4f7242980722d8586e89395ce2',
#   'text': 'From the Drawing by Fleming Williams',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'cce20984fb12a38f748dce27d5872fca',
#   'text': 'WINTER\nSPORTS',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '1ffc8876667ab88f275ef4fe3bf53bb9',
#   'text': 'IN SWITZERLAND',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '60547bd9ab11c5459a6fffa441ed70d6',
#   'text': 'BY',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'b399586997353e442796be85b5827e86',
#   'text': 'E. F. BENSON',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '5e6464633805d30d639f2d961515c93a',
#   'text': 'WITH 12 FULL-PAGE ILLUSTRATIONS IN COLOUR BY',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'fc1a7ee45ef9cd01165da16db8bf476c',
#   'text': 'C. FLEMING WILLIAMS',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '98acf8b40967602895656a289fae5711',
#   'text': 'AND 47 REPRODUCTIONS FROM PHOTOGRAPHS BY',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'db65fa0d4ad643a2374e356fd17b8874',
#   'text': 'MRS. AUBREY LE BLOND',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'c5a0d0ad7a5b0635bc6c0a3dd6998313',
#   'text': 'LONDON',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'UncategorizedText',
#   'element_id': 'b0f3b556bba346e9d40dacd01e0b7e1e',
#   'text': 'GEORGE ALLEN & COMPANY, LTD.',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'parent_id': 'c5a0d0ad7a5b0635bc6c0a3dd6998313',
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '87d1ae74eab3bd5d769fc821f2ba5ee6',
#   'text': '44 & 45 RATHBONE PLACE',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'UncategorizedText',
#   'element_id': '3b1fba0616142d348bd8a977e3aa3d65',
#   'text': '1913',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'parent_id': '87d1ae74eab3bd5d769fc821f2ba5ee6',
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'NarrativeText',
#   'element_id': 'ff2efcd4f2ef7a894bc29803895790ce',
#   'text': '[All rights reserved]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'parent_id': '87d1ae74eab3bd5d769fc821f2ba5ee6',
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'NarrativeText',
#   'element_id': 'c16730e3ef4b7fd901346e355d7e11ac',
#   'text': 'Printed by',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'parent_id': '87d1ae74eab3bd5d769fc821f2ba5ee6',
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'NarrativeText',
#   'element_id': 'c16730e3ef4b7fd901346e355d7e11ac',
#   'text': 'Printed by',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'parent_id': '87d1ae74eab3bd5d769fc821f2ba5ee6',
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '0cdb948cf6957d64732bf3aa6fdff98f',
#   'text': 'Ballantyne, Hanson\n& Co.',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'b7ed7551a26a6fbc4617c7f59b44b792',
#   'text': 'at the Ballantyne Press, Edinburgh',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'eabe6aca2f0dcdbddb32c8f06e6edfa1',
#   'text': 'CONTENTS',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Table',
#   'element_id': '6f8283d84704f72311e8e04ec98fb830',
#   'text': 'CHAP. PAGE I. The Sun-seeker 1 II. Rinks and Skaters 23 III. Tees and Crampits 79 IV. Tobogganing 115 V. Ice-Hockey 129 VI. Ski-ing 137 VII. Notes on Winter Resorts 167 VIII. For Parents and Guardians 191',
#   'metadata': {'text_as_html': '<table><tr><td>CHAP.</td><td></td><td>PAGE</td></tr><tr><td>I.</td><td>The Sun-seeker</td><td>1</td></tr><tr><td>II.</td><td>Rinks and Skaters</td><td>23</td></tr><tr><td>III.</td><td>Tees and Crampits</td><td>79</td></tr><tr><td>IV.</td><td>Tobogganing</td><td>115</td></tr><tr><td>V.</td><td>Ice-Hockey</td><td>129</td></tr><tr><td>VI.</td><td>Ski-ing</td><td>137</td></tr><tr><td>VII.</td><td>Notes on Winter Resorts</td><td>167</td></tr><tr><td>VIII.</td><td>For Parents and Guardians</td><td>191</td></tr></table>',
#    'page_number': 2,
#    'languages': ['eng'],
#    'parent_id': 
integrates in its fall, so that it reaches the valley more in wreaths\nof mist than in solid water, and collects again from the dripping rocks;\nwhile in winter its diminished volume is further spent in the\nmanufacture of the huge icicles that fringe the edge of its\nleaping-place, and hang in great streamers, the beard and hair, you\nwould say, of the very Frost-king himself, who sits at ease on this\nprecipitous throne. Little water to-day runs away from where the clouds\nof mist and water-smoke fall on the rocks, for most of them are frozen\nthere, and a layer of ice covers the boulders where they come to earth.\nFor here, so engorged lies the valley, so close to the great rampart of\nthe Oberland, that the sun which blazed on Interlaken has not yet\nsurmounted the barrier of mountain-peaks.',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'parent_id': 'd9725192dcad4b316b9000b2e0b9d803',
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'NarrativeText',
#   'element_id': '5cd99fb35ccf9834ab3bda177165c148',
#   'text': 'Parallel with the Staubbach, and up a hillside which appears hardly\nless sheer than the precipice itself, runs the funicular railway which\nleads to the Mürren-plateau. At first sight it seems as if it must be\nmeant for a practical joke, constructed by humorous engineers to\nastonish the weak minds of travellers, and, though practical from the\npoint of view of a joke, to be perfectly impracticable\nas a means of conveyance. Its steepness is that of disordered images\nseen in a dream, and it was with a sense of utter incredulity that I\nfirst took my place in one of the small wooden compartments and was\nlocked in by an apparently sane and serious conductor. He blew a\nwhistle, or a bell sounded, just as is done on real lines of traffic,\nand immediately afterwards we began to ascend that impossible line of\nrails, sauntering with smooth and steady progress up that ridiculous\nprecipice. More amazing still we soon observed a similar car sauntering\nsteadily down it, just strolling down, even as we were strolling up. We\nmet, we passed, and I had a vision of passengers smoking and chatting,\nas if nothing in the least remarkable was happening and imminent death\ndid not await us all....',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'parent_id': 'd9725192dcad4b316b9000b2e0b9d803',
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'NarrativeText',
#   'element_id': '1959c2211dc645381de46d240d76ed25',
# ...
#   'text': '• You comply with all other terms of this agreement for free\ndistribution of Project Gutenberg™ works.',
#   'metadata': {'page_number': 6,
#    'languages': ['eng'],
#    'parent_id': '471fcbd48a09bcef0008cfec05b36b2a',
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'NarrativeText',
#   'element_id': 'a038d257758fd40ddc181c1f7c4ee7fc',
#   'text': '1.E.9. If you wish to charge a fee or distribute a Project Gutenberg™\nelectronic work or group of works on different terms than are set forth\nin this agreement, you must obtain permission in writing from the\nProject Gutenberg Literary Archive Foundation, the manager of the\nProject Gutenberg™ trademark. Contact the Foundation as set forth in\nSection 3 below.',
#   'metadata': {'page_number': 6,
#    'languages': ['eng'],
#    'parent_id': '471fcbd48a09bcef0008cfec05b36b2a',
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'UncategorizedText',
#   'element_id': '98ab8f164014189126838e285d5d9178',
#   'text': '1.F.',
#   'metadata': {'page_number': 6,
#    'languages': ['eng'],
#    'parent_id': '471fcbd48a09bcef0008cfec05b36b2a',
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'NarrativeText',
#   'element_id': 'e9acd835792ae13aaa283403038488f8',
#   'text': '1.F.1. Project Gutenberg volunteers and employees expend considerable\neffort to identify, do copyright research on, transcribe and proofread\nworks not protected by U.S. copyright law in creating the Project\nGutenberg™ collection. Despite these efforts, Project Gutenberg™\nelectronic works, and the medium on which they may be stored, may\ncontain “Defects,” such as, but not limited to, incomplete, inaccurate\nor corrupt data, transcription errors, a copyright or other intellectual\nproperty infringement, a defective or damaged disk or other medium, a\ncomputer virus, or computer codes that damage or cannot be read by your\nequipment.',
#   'metadata': {'page_number': 6,
#    'languages': ['eng'],
#    'parent_id': '471fcbd48a09bcef0008cfec05b36b2a',
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'NarrativeText',
#   'element_id': 'db4ed7ed34ea121ed1ced5b2f11480c7',
#   'text': '1.F.2. LIMITED WARRANTY, DISCLAIMER OF DAMAGES - Except for the “Right\nof Replacement or Refund” described in paragraph 1.F.3, the Project\nGutenberg Literary Archive Foundation, the owner of the Project\nGutenberg™ trademark, and any other party distributing a Project\nGutenberg™ electronic work under this agreement, disclaim all liability\nto you for damages, costs and expenses, including legal fees. YOU AGREE\nTHAT YOU HAVE NO REMEDIES FOR NEGLIGENCE, STRICT LIABILITY, BREACH OF\nWARRANTY OR BREACH OF CONTRACT EXCEPT THOSE PROVIDED IN PARAGRAPH 1.F.3.\nYOU AGREE THAT THE FOUNDATION, THE TRADEMARK OWNER, AND ANY DISTRIBUTOR\nUNDER THIS AGREEMENT WILL NOT BE LIABLE TO YOU FOR ACTUAL, DIRECT,\nINDIRECT, CONSEQUENTIAL, PUNITIVE OR INCIDENTAL DAMAGES EVEN IF YOU GIVE\nNOTICE OF THE POSSIBILITY OF SUCH DAMAGE.',
#   'metadata': {'page_number': 6,
#    'languages': ['eng'],
#    'parent_id': '471fcbd48a09bcef0008cfec05b36b2a',
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'NarrativeText',
#   'element_id': 'ed3cfe8c2b97a7fa5f43b665720fab95',
#   'text': '1.F.3. LIMITED RIGHT OF REPLACEMENT OR REFUND - If you discover a defect\nin this electronic work within 90 days of receiving it, you can receive\na refund of the money (if any) you paid for it by sending a written\nexplanation to the person you received the work from. If you received\nthe work on a physical medium, you must return the medium with your\nwritten explanation. The person or entity that provided you with the\ndefective work may elect to provide a replacement copy in lieu of a\nrefund. If you received the work electronically, the person or entity\nproviding it to you may choose to give you a second opportunity to\nreceive the work electronically in lieu of a refund. If the second copy\nis also defective, you may demand a refund in writing without further\nopportunities to fix the problem.',
#   'metadata': {'page_number': 6,
#    'languages': ['eng'],
#    'parent_id': '471fcbd48a09bcef0008cfec05b36b2a',
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'UncategorizedText',
#   'element_id': '24b1c443f875db95f91400325e736234',
#   'text': '1.F.4. Except for the limited right of replacement or refund set forth\nin paragraph 1.F.3, this work is provided to you ‘AS-IS’, WITH NO OTHER\nWARRANTIES OF ANY KIND, EXPRESS OR IMPLIED, INCLUDING BUT NOT LIMITED TO\nWARRANTIES OF MERCHANTABILITY OR FITNESS FOR ANY PURPOSE.',
#   'metadata': {'page_number': 6,
#    'languages': ['eng'],
#    'parent_id': '471fcbd48a09bcef0008cfec05b36b2a',
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'NarrativeText',
#   'element_id': '03a810543f45a9ce7725d318ca353464',
#   'text': '1.F.5. Some states do not allow disclaimers of certain implied\nwarranties or the exclusion or limitation of certain types of damages.\nIf any disclaimer or limitation set forth in this agreement violates the\nlaw of the state applicable to this agreement, the agreement shall be\ninterpreted to make the maximum disclaimer or limitation permitted by\nthe applicable state law. The invalidity or unenforceability of any\nprovision of this agreement shall not void the remaining provisions.',
#   'metadata': {'page_number': 6,
#    'languages': ['eng'],
#    'parent_id': '471fcbd48a09bcef0008cfec05b36b2a',
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'NarrativeText',
#   'element_id': 'e37e9c8377bebefc30ebeb5ecee3a6fc',
#   'text': '1.F.6. INDEMNITY - You agree to indemnify and hold the Foundation, the\ntrademark owner, any agent or employee of the Foundation, anyone\nproviding copies of Project Gutenberg™ electronic works in accordance\nwith this agreement, and any volunteers associated with the production,\npromotion and distribution of Project Gutenberg™ electronic works,\nharmless from all liability, costs and expenses, including legal fees,\nthat arise directly or indirectly from any of the following which you do\nor cause to occur: (a) distribution of this or any Project Gutenberg™\nwork, (b) alteration, modification, or additions or deletions to any\nProject Gutenberg™ work, and (c) any Defect you cause.',
#   'metadata': {'page_number': 6,
#    'languages': ['eng'],
#    'parent_id': '471fcbd48a09bcef0008cfec05b36b2a',
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'ac6f3bc8072da317ca9140b2bfa56533',
#   'text': 'Section 2. Information about the Mission of Project Gutenberg™',
#   'metadata': {'page_number': 6,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'NarrativeText',
#   'element_id': '009f31cc3c96df92ac2a6ff14d140c2e',
#   'text': 'Project Gutenberg™ is synonymous with the free distribution of\nelectronic works in formats readable by the widest variety of computers\nincluding obsolete, old, middle-aged and new computers. It exists\nbecause of the efforts of hundreds of volunteers and donations from\npeople in all walks of life.',
#   'metadata': {'page_number': 6,
#    'languages': ['eng'],
#    'parent_id': 'ac6f3bc8072da317ca9140b2bfa56533',
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'NarrativeText',
#   'element_id': '14ac62ee37e2fbb1ecd59e2c3e9ec035',
#   'text': 'Volunteers and financial support to provide volunteers with the\nassistance they need are critical to reaching Project Gutenberg™’s goals\nand ensuring that the Project Gutenberg™ collection will remain freely\navailable for generations to come. In 2001, the Project Gutenberg\nLiterary Archive Foundation was created to provide a secure and\npermanent future for Project Gutenberg™ and future generations. To learn\nmore about the Project Gutenberg Literary Archive Foundation and how\nyour efforts and donations can help, see Sections 3 and 4 and the\nFoundation information page at www.gutenberg.org.',
#   'metadata': {'page_number': 6,
#    'languages': ['eng'],
#    'parent_id': 'ac6f3bc8072da317ca9140b2bfa56533',
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '02084f5715b457c0866b120d5d89959c',
#   'text': 'Section 3. Information about the Project Gutenberg Literary Archive\nFoundation',
#   'metadata': {'page_number': 6,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'NarrativeText',
#   'element_id': '6a40e71e13704a6f9ffa3f69354f8ae4',
#   'text': 'The Project Gutenberg Literary Archive Foundation is a non-profit\n501(c)(3) educational corporation organized under the laws of the state\nof Mississippi and granted tax exempt status by the Internal Revenue\nService. The Foundation’s EIN or federal tax identification number is\n64-6221541. Contributions to the Project Gutenberg Literary Archive\nFoundation are tax deductible to the full extent permitted by U.S.\nfederal laws and your state’s laws.',
#   'metadata': {'page_number': 6,
#    'languages': ['eng'],
#    'parent_id': '02084f5715b457c0866b120d5d89959c',
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'NarrativeText',
#   'element_id': 'd667214f49dc92367540468f0b2c3bbf',
#   'text': 'The Foundation’s business office is located at 809 North 1500 West, Salt\nLake City, UT 84116, (801) 596-1887. Email contact links and up to date\ncontact information can be found at the Foundation’s website and\nofficial page at www.gutenberg.org/contact',
#   'metadata': {'page_number': 6,
#    'languages': ['eng'],
#    'parent_id': '02084f5715b457c0866b120d5d89959c',
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '3fc7af460165cbf738d34a2dc355291e',
#   'text': 'Section 4. Information about Donations to the Project Gutenberg Literary\nArchive Foundation',
#   'metadata': {'page_number': 6,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'NarrativeText',
#   'element_id': '29ed90fa9d4f9af225a3b2cc98a58cd4',
#   'text': 'Project Gutenberg™ depends upon and cannot survive without widespread\npublic support and donations to carry out its mission of increasing the\nnumber of public domain and licensed works that can be freely\ndistributed in machine-readable form accessible by the widest array of\nequipment including outdated equipment. Many small donations ($1 to\n$5,000) are particularly important to maintaining tax exempt status with\nthe IRS.',
#   'metadata': {'page_number': 6,
#    'languages': ['eng'],
#    'parent_id': '3fc7af460165cbf738d34a2dc355291e',
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'NarrativeText',
#   'element_id': '01e619a28c0418e2213e168b6b71b634',
#   'text': '\nThe Foundation is committed to complying with the laws regulating\ncharities and charitable donations in all 50 states of the United\nStates. Compliance requirements are not uniform and it takes a\nconsiderable effort, much paperwork and many fees to meet and keep up\nwith these requirements. We do not solicit donations in locations where\nwe have not received written confirmation of compliance. To SEND\nDONATIONS or determine the status of compliance for any particular state\nvisit ',
#   'metadata': {'page_number': 6,
#    'languages': ['eng'],
#    'parent_id': '3fc7af460165cbf738d34a2dc355291e',
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '51055211bb4994c62bb88c832f1aa7ae',
#   'text': 'www.gutenberg.org/donate.',
#   'metadata': {'page_number': 6,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'NarrativeText',
#   'element_id': '26a53e991e357745c8873b9e21477783',
#   'text': 'While we cannot and do not solicit contributions from states where we\nhave not met the solicitation requirements, we know of no prohibition\nagainst accepting unsolicited donations from donors in such states who\napproach us with offers to donate.',
#   'metadata': {'page_number': 6,
#    'languages': ['eng'],
#    'parent_id': '51055211bb4994c62bb88c832f1aa7ae',
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'NarrativeText',
#   'element_id': '5a5d4da87d1eea3cea66a0c997ae3875',
#   'text': 'International donations are gratefully accepted, but we cannot make any\nstatements concerning tax treatment of donations received from outside\nthe United States. U.S. laws alone swamp our small staff.',
#   'metadata': {'page_number': 6,
#    'languages': ['eng'],
#    'parent_id': '51055211bb4994c62bb88c832f1aa7ae',
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'NarrativeText',
#   'element_id': '30964955f10e56afbbd00ee3ffeec687',
#   'text': 'Please check the Project Gutenberg web pages for current donation\nmethods and addresses. Donations are accepted in a number of other ways\nincluding checks, online payments and credit card donations. To donate,\nplease visit: www.gutenberg.org/donate',
#   'metadata': {'page_number': 6,
#    'languages': ['eng'],
#    'parent_id': '51055211bb4994c62bb88c832f1aa7ae',
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '496828ca399919ead9af5f1e82141f7f',
#   'text': 'Section 5. General Information About Project Gutenberg™ electronic works',
#   'metadata': {'page_number': 6,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'NarrativeText',
#   'element_id': '95efa98c1809ee3bb0657c8937649eca',
#   'text': 'Professor Michael S. Hart was the originator of the Project Gutenberg™\nconcept of a library of electronic works that could be freely shared\nwith anyone. For forty years, he produced and distributed Project\nGutenberg™ eBooks with only a loose network of volunteer support.',
#   'metadata': {'page_number': 6,
#    'languages': ['eng'],
#    'parent_id': '496828ca399919ead9af5f1e82141f7f',
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'NarrativeText',
#   'element_id': 'c4576b9d0be5810e89c5826f454fa398',
#   'text': 'Project Gutenberg™ eBooks are often created from several printed\neditions, all of which are confirmed as not protected by copyright in\nthe U.S. unless a copyright notice is included. Thus, we do not\nnecessarily keep eBooks in compliance with any particular paper edition.',
#   'metadata': {'page_number': 6,
#    'languages': ['eng'],
#    'parent_id': '496828ca399919ead9af5f1e82141f7f',
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'NarrativeText',
#   'element_id': '110baa27a61f90dccaefdbcbb0693278',
#   'text': '\nMost people start at our website which has the main PG search facility:\n',
#   'metadata': {'page_number': 6,
#    'languages': ['eng'],
#    'parent_id': '496828ca399919ead9af5f1e82141f7f',
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '1d59e0f7ef1034f07023aa35b0dc2731',
#   'text': 'www.gutenberg.org.',
#   'metadata': {'page_number': 6,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'NarrativeText',
#   'element_id': '736a75545c62284e5285977d64557293',
#   'text': 'This website includes information about Project Gutenberg™, including\nhow to make donations to the Project Gutenberg Literary Archive\nFoundation, how to help produce our new eBooks, and how to subscribe to\nour email newsletter to hear about new eBooks.',
#   'metadata': {'page_number': 6,
#    'languages': ['eng'],
#    'parent_id': '1d59e0f7ef1034f07023aa35b0dc2731',
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}}]

# %%
JSON(json.dumps(res.elements[10:15], indent=2))
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/IPython/core/display.py:618: UserWarning: JSON expects JSONable dict or list, not JSON strings
#   warnings.warn("JSON expects JSONable dict or list, not JSON strings")

# %%
[x for x in res.elements if x['type']=='Title' and 'hockey' in x['text'].lower()]
# Out:
# [{'type': 'Title',
#   'element_id': 'dcea2070d3d9171c9c817967917ca77b',
#   'text': 'ICE-HOCKEY',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '8738b816c128ffcafa1fbfedd3be5f44',
#   'text': 'ICE HOCKEY',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}}]

# %%
[x for x in res.elements if x['type']=='Title' ] #and 'hockey' in x['text'].lower()]
# Out:
# [{'type': 'Title',
#   'element_id': '0c6fff519d8892b1783ead469b230320',
#   'text': 'The Project Gutenberg eBook of Winter Sports in\nSwitzerland, by E. F. Benson',
#   'metadata': {'page_number': 1,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '4a7aedb1f1383e75bb0ee85e359cee60',
#   'text': 'Title: Winter Sports in Switzerland',
#   'metadata': {'page_number': 1,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '395a1ca8c9a7512b4ef7910c383f02f0',
#   'text': 'Author: E. F. Benson',
#   'metadata': {'page_number': 1,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'd13cc748dfa64302f1cacc7df9eb8ce6',
#   'text': 'Illustrator: C. Fleming Williams',
#   'metadata': {'page_number': 1,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'a5254421f3a21ec28163a78d8fcc5765',
#   'text': 'Photographer: Mrs. Aubrey Le Blond',
#   'metadata': {'page_number': 1,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'e25742b8ac3c8efa7593309396dfb342',
#   'text': 'Release date: August 23, 2019 [EBook #60153]',
#   'metadata': {'page_number': 1,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'b57efaf39e21b67232bab14763e8c43f',
#   'text': 'Language: English',
#   'metadata': {'page_number': 1,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '1917835b784d18dabafdb3d112f1f45e',
#   'text': 'Credits: Produced by Chuck Greif and the Online\nDistributed',
#   'metadata': {'page_number': 1,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'e1b22c3e168288282d72f5c55043859e',
#   'text': '[Image unavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'a293506132f847d3df66f9d8de03b881',
#   'text': 'THE EIGER',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '82622f4f7242980722d8586e89395ce2',
#   'text': 'From the Drawing by Fleming Williams',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'cce20984fb12a38f748dce27d5872fca',
#   'text': 'WINTER\nSPORTS',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '1ffc8876667ab88f275ef4fe3bf53bb9',
#   'text': 'IN SWITZERLAND',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '60547bd9ab11c5459a6fffa441ed70d6',
#   'text': 'BY',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'b399586997353e442796be85b5827e86',
#   'text': 'E. F. BENSON',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '5e6464633805d30d639f2d961515c93a',
#   'text': 'WITH 12 FULL-PAGE ILLUSTRATIONS IN COLOUR BY',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'fc1a7ee45ef9cd01165da16db8bf476c',
#   'text': 'C. FLEMING WILLIAMS',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '98acf8b40967602895656a289fae5711',
#   'text': 'AND 47 REPRODUCTIONS FROM PHOTOGRAPHS BY',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'db65fa0d4ad643a2374e356fd17b8874',
#   'text': 'MRS. AUBREY LE BLOND',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'c5a0d0ad7a5b0635bc6c0a3dd6998313',
#   'text': 'LONDON',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '87d1ae74eab3bd5d769fc821f2ba5ee6',
#   'text': '44 & 45 RATHBONE PLACE',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '0cdb948cf6957d64732bf3aa6fdff98f',
#   'text': 'Ballantyne, Hanson\n& Co.',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'b7ed7551a26a6fbc4617c7f59b44b792',
#   'text': 'at the Ballantyne Press, Edinburgh',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'eabe6aca2f0dcdbddb32c8f06e6edfa1',
#   'text': 'CONTENTS',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '0fdd15e3fc0990ad52a13cd29e50165e',
#   'text': 'ILLUSTRATIONS',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '8d7fac916c606cde6631d8e96b00bacd',
#   'text': 'WINTER SPORTS IN SWITZERLAND',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '611230d964c565c5437b72fcb3c6d93b',
#   'text': 'CHAPTER\nI',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'd9725192dcad4b316b9000b2e0b9d803',
#   'text': 'THE SUN-SEEKER',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '3621d508b3474754956b6b29b09a6a3f',
#   'text': '’Tis better; then the silence grows',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '93420c2344e54f3e139102b81a6599e6',
#   'text': '[Image\nunavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'f09dadbc57730f03e9e3d94026e8d7b3',
#   'text': 'Plate I',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '537847228bca60003ce775f34631e7e7',
#   'text': 'WINTER SUNLIGHT',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '93420c2344e54f3e139102b81a6599e6',
#   'text': '[Image\nunavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'e74ac519c30eb37377857e561603b346',
#   'text': 'Plate II',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '5a64b810a94c5de9c04b942d97360f9a',
#   'text': 'BY THE STREAM-SIDE',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '93420c2344e54f3e139102b81a6599e6',
#   'text': '[Image\nunavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'ed7d30c131721cf41d5ee7df52822905',
#   'text': 'Plate III',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'bd71cbdbdffceb4e420e3462a02b922d',
#   'text': 'HOAR-FROST',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '93420c2344e54f3e139102b81a6599e6',
#   'text': '[Image\nunavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '5ea540cd8c8153cba1caa61d8be1c81f',
#   'text': 'Plate IV',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '703e16ea5e7bff7066a69098803bb42e',
#   'text': 'JEWELS OF THE FROST',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '93420c2344e54f3e139102b81a6599e6',
#   'text': '[Image\nunavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'f726ffe698dce4f9b53dcc226ce93d72',
#   'text': 'Plate V',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '63bedc7d3cdca633c81931653ad42073',
#   'text': 'BLACK ICE ON THE SILS LAKE',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '93420c2344e54f3e139102b81a6599e6',
#   'text': '[Image\nunavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '8743335fb8f056ca814fafc90f463f7c',
#   'text': 'Plate VI',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '2ec0afee5b68bc25168f319fc7fab50d',
#   'text': 'THE BUDDING ICE FLOWERS',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '93420c2344e54f3e139102b81a6599e6',
#   'text': '[Image\nunavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '84c3b68a63f3a9d6ba6d827da35f6f01',
#   'text': 'Plate VII',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'c5470383279e5ccd69f8b93d58e44798',
#   'text': 'THE FULL-BLOWN ICE FLOWERS',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '909e83f622de3df1c560c0ab9fa42d86',
#   'text': '(twenty-four hours later)',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '93420c2344e54f3e139102b81a6599e6',
#   'text': '[Image\nunavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'ad3f0bd148d384985d97fea1e1950d98',
#   'text': 'Plate VIII',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '4448a214b1ecf16b1b73e731a4d84a5d',
#   'text': 'ICE FLOWERS IN DETAIL',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '93420c2344e54f3e139102b81a6599e6',
#   'text': '[Image\nunavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '82a8b9784f9ad4703b1216add04f2d55',
#   'text': 'Plate IX',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '3c6fe146797d9b6241263eb763429da8',
#   'text': 'MAGNIFIED ICE FLOWERS',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '93420c2344e54f3e139102b81a6599e6',
#   'text': '[Image\nunavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '40df5cc7fb47f3f402f4ac54669e25b1',
#   'text': 'Plate X',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'd906d40aaef98e126cde4817e814d916',
#   'text': 'WINTER MOONLIGHT',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '786a374d9bd0ef1d835d89b147c170db',
#   'text': 'CHAPTER\nII',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '85a84e38543ad3417cdef25e3616cbbc',
#   'text': 'RINKS AND SKATERS',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'e1b22c3e168288282d72f5c55043859e',
#   'text': '[Image unavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '349866f4a9bdfb4716705fcfaa4b6c45',
#   'text': 'SKATING—ENGLISH STYLE',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '82622f4f7242980722d8586e89395ce2',
#   'text': 'From the Drawing by Fleming Williams',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'e1b22c3e168288282d72f5c55043859e',
#   'text': '[Image unavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '900e0891af2e3a190ccdb9096134382d',
#   'text': 'SKATING—CONTINENTAL STYLE',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '82622f4f7242980722d8586e89395ce2',
#   'text': 'From the Drawing by Fleming Williams',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '7810afefd7ab14d3e8c02653416b8d17',
#   'text': 'Thus:',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '93420c2344e54f3e139102b81a6599e6',
#   'text': '[Image\nunavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '93420c2344e54f3e139102b81a6599e6',
#   'text': '[Image\nunavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '93420c2344e54f3e139102b81a6599e6',
#   'text': '[Image\nunavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '93420c2344e54f3e139102b81a6599e6',
#   'text': '[Image\nunavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '93420c2344e54f3e139102b81a6599e6',
#   'text': '[Image\nunavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '93420c2344e54f3e139102b81a6599e6',
#   'text': '[Image\nunavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '990690253acf17246713107fa1ffb2a5',
#   'text': 'THIRD-CLASS\nTEST',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '75d7d613da8091efdf978edab1730622',
#   'text': 'SECOND-CLASS\nTEST',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'a3aabbbbb5e61d8c417f7b708129f37b',
#   'text': 'FIRST-CLASS\nTEST',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'bc272940e494acf9441070d3eb4b79f6',
#   'text': 'Section A',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '5c0114a68e34a23e9411f13e3c48fb9b',
#   'text': 'Part I',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '893d447f1112b40196e60c85d8358cfc',
#   'text': '3. Twice back—and forward three about, change, meet.',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'ce6d62fc84568895f2f424c7718cb7cb',
#   'text': '7. Twice back centre change, three, meet.',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'f4881bcc71080b30bf572f14937e93af',
#   'text': '9. Twice back—and forward two threes, pass, meet.',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '8d7c34bdf7c8e7307be9269e486c239d',
#   'text': '10. Twice back two threes, off pass, meet.',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '247de7538be703236e4fbac8020c32b7',
#   'text': '11. Inside twice back—and forward inside two threes, meet.',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '148b65833777b97f6433ce9a80e5c91d',
#   'text': 'Part II',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '04e392556b94bc61c3b428cc5045f626',
#   'text': 'Section B',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '5c0114a68e34a23e9411f13e3c48fb9b',
#   'text': 'Part I',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '148b65833777b97f6433ce9a80e5c91d',
#   'text': 'Part II',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'cb70df7b3aca163534c1ebaaa0df0650',
#   'text': 'Reverse\nQ’s',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '9186728edcd714a519702552373b38e0',
#   'text': 'International Style',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'ee57602648499483328991a46fc5af53',
#   'text': 'Second-class Test',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '76d24e43b89f60f92963c0546c2f6a51',
#   'text': 'Compulsory\nFigures',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '9819a763f5522b6d3dd0088e23f35255',
#   'text': 'First-class Test',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'a2b0edb3e5c6a7bb99c27126c695a9be',
#   'text': '(b) For the manner of performance up to a maximum of 6\nmarks.',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '76d24e43b89f60f92963c0546c2f6a51',
#   'text': 'Compulsory\nFigures',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '93420c2344e54f3e139102b81a6599e6',
#   'text': '[Image\nunavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'a40f696eda1a56d0ea8c211b67e09348',
#   'text': 'Plate XI',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '9a323117d0387b840e3b95a4d90376c9',
#   'text': 'A WINTER HARVEST',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '93420c2344e54f3e139102b81a6599e6',
#   'text': '[Image\nunavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '37d405ee4683d0829f86d0c75cbccdd5',
#   'text': 'Plate XII',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '7f0b6baa9a527e075c01faf5367a8bf2',
#   'text': 'CLEARING THE SNOW FROM THE RINK',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '93420c2344e54f3e139102b81a6599e6',
#   'text': '[Image\nunavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'd4a4bcf4d3d7e8fefac49facfa565acb',
#   'text': 'Plate XIII',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '25c1eadb02a35af7e30cfc58a2d74fa1',
#   'text': 'SPRINKLING THE RINK, CHÂTEAU D’OEX',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '93420c2344e54f3e139102b81a6599e6',
#   'text': '[Image\nunavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'c8993a004e0e7a9127d5962d7fdef51d',
#   'text': 'Plate XIV',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '66acc32db14a6674d62974306b820466',
#   'text': 'PUBLIC RINK, DAVOS',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '93420c2344e54f3e139102b81a6599e6',
#   'text': '[Image\nunavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '9742a5844cd30d7f9ac51630b3198047',
#   'text': 'Plate XV',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'de2d9433bbb95cb7a5f142aad1e3166f',
#   'text': 'SKATING-RINK AT MÜRREN',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '93420c2344e54f3e139102b81a6599e6',
#   'text': '[Image\nunavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '417b37ad45c12c7e4f8024aee0ff5f47',
#   'text': 'Plate XVI',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '01b4776701e24a333bd8c012ae2bf9c3',
#   'text': 'SKATING-RINK AT CHÂTEAU D’OEX',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '688d7eebc467572dca76e2d404678c82',
#   'text': 'CHAPTER\nIII',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '5229c64d88a2a9bd98581911deedc70c',
#   'text': 'TEES AND CRAMPITS',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'f5b51af34eef27199fa8c35d68609edb',
#   'text': '(b) A “sweeping score” across each 7-foot circle and through\neach tee.',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'e1b22c3e168288282d72f5c55043859e',
#   'text': '[Image unavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '82622f4f7242980722d8586e89395ce2',
#   'text': 'From the Drawing by Fleming Williams',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'c2b10dcbc1828df6080d9ea3cd9de6b6',
#   'text': 'Skip 2. No.',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'c2b10dcbc1828df6080d9ea3cd9de6b6',
#   'text': 'Skip 2. No.',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'c2b10dcbc1828df6080d9ea3cd9de6b6',
#   'text': 'Skip 2. No.',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'c2b10dcbc1828df6080d9ea3cd9de6b6',
#   'text': 'Skip 2. No.',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'aa20811a40a699c217d7a6a921a8ea8e',
#   'text': '(Long pause.)',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '613f27086f28ec8f7621f7d45914f94c',
#   'text': 'No. 3. Well?',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '93420c2344e54f3e139102b81a6599e6',
#   'text': '[Image\nunavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '372faa20f09dd373b4f1100a137b211b',
#   'text': 'Plate XVII',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'd3ca5e19363414d1d60057e16494c631',
#   'text': 'CURLING',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '93420c2344e54f3e139102b81a6599e6',
#   'text': '[Image\nunavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '6cc9a30e255067d4a032e13ffd46f6b7',
#   'text': 'Plate XVIII',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '7c26a5d5cf1e13d26d024f0b0404d0a1',
#   'text': 'CURLING AT MURREN',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '93420c2344e54f3e139102b81a6599e6',
#   'text': '[Image\nunavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'b9a6ed9e8bc6cb1b6726e7d6377b0d8c',
#   'text': 'Plate XIX',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'bdf62274334a021410f2a2fb7b307b2b',
#   'text': 'THE THREE KULM RINKS',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '93420c2344e54f3e139102b81a6599e6',
#   'text': '[Image\nunavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '0154ebe1527c55636a8f545ae6181e90',
#   'text': 'Plate XX',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '6bf263d4e4ca595c5aaeddda9ed33d03',
#   'text': 'LADIES’ CURLING MATCH, ST. MORITZ',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '5a17816adda849fb7599343f23cb86bb',
#   'text': 'CHAPTER\nIV',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'c9d7976b507c3385bb6bbd7e06c64ca1',
#   'text': 'TOBOGGANING',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'f002b5670abf5378015057b4bdb0be45',
#   'text': '(ii) Proceeding—as quickly as possible—down artificial ice-runs.',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'e1b22c3e168288282d72f5c55043859e',
#   'text': '[Image unavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '82622f4f7242980722d8586e89395ce2',
#   'text': 'From the Drawing by Fleming Williams',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '441e86cacde33d5458bc43d25904486d',
#   'text': 'Ice-runs',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'e1b22c3e168288282d72f5c55043859e',
#   'text': '[Image unavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '33cd76417d7266c2c4f4f454b4f5ea12',
#   'text': 'ON THE CRESTA RUN',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '82622f4f7242980722d8586e89395ce2',
#   'text': 'From the Drawing by Fleming Williams',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'cfe76a92ac2fc9eaeacb896bcb6d6606',
#   'text': 'Bobsleighing\n(or Bobbing)',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'e1b22c3e168288282d72f5c55043859e',
#   'text': '[Image unavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '3f7e038f542c19490f15939df4311de4',
#   'text': 'TAILING',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '82622f4f7242980722d8586e89395ce2',
#   'text': 'From the Drawing by Fleming Williams',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '93420c2344e54f3e139102b81a6599e6',
#   'text': '[Image\nunavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'cdb4461ae293e5d52c748c93d9987ae8',
#   'text': 'Plate XXI',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '93420c2344e54f3e139102b81a6599e6',
#   'text': '[Image\nunavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'c758d86a4ac236d07f26116172aba218',
#   'text': 'Plate XXII',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'dac5d2a2aa335c5dbd18f47646e9ee89',
#   'text': 'THE TOP OF THE CRESTA, ST. MORITZ',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '93420c2344e54f3e139102b81a6599e6',
#   'text': '[Image\nunavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '1f20db7f804fe08f2ce02337f3155478',
#   'text': 'Plate XXIII',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'd5ddfae0b1002335fb13a9c1cd3f0202',
#   'text': 'STARTING ON THE CRESTA',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '93420c2344e54f3e139102b81a6599e6',
#   'text': '[Image\nunavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'a8b87aa46cd90fd347214165c3496953',
#   'text': 'Plate XXIV',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '725c18943de7544b1b309e2bd6d9dca3',
#   'text': 'CHURCH LEAP, CRESTA RUN',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '93420c2344e54f3e139102b81a6599e6',
#   'text': '[Image\nunavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'fc4d94414889f0ef03c7844197ac4542',
#   'text': 'Plate XXV',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '725c18943de7544b1b309e2bd6d9dca3',
#   'text': 'CHURCH LEAP, CRESTA RUN',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '93420c2344e54f3e139102b81a6599e6',
#   'text': '[Image\nunavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '23934d6f891993a98c7ea2a22e08a7dc',
#   'text': 'Plate XXVI',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'd795abc519f513ff289ad80c68095b83',
#   'text': '“BATTLEDORE” CORNER, CRESTA',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '93420c2344e54f3e139102b81a6599e6',
#   'text': '[Image\nunavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'c68991a91ebc3bd61ac17877a9956dc1',
#   'text': 'Plate XXVII',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '2c9612783b2831c0ba7486b7ec788287',
#   'text': 'CROSSING THE ROAD, CRESTA',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '93420c2344e54f3e139102b81a6599e6',
#   'text': '[Image\nunavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '2ecec0d579a470cb2c8e2b71d7e41b3d',
#   'text': 'Plate XXVIII',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '4c8a4d0660afa8809c6bcb8ea89f5561',
#   'text': 'NEAR THE FINISH ON THE CRESTA',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '93420c2344e54f3e139102b81a6599e6',
#   'text': '[Image\nunavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'a28023178b3cb44bee5007f70300efba',
#   'text': 'Plate XXIX',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '314f386e467d1fc976004238ca43b5fb',
#   'text': 'BOB-RUN, ST. MORITZ: IN THE LARCH WOODS',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '93420c2344e54f3e139102b81a6599e6',
#   'text': '[Image\nunavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'c5920cf86888a9b74202b831608c27a9',
#   'text': 'Plate XXX',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'f03f4575e13741a36b2f9b804446718a',
#   'text': 'ROUNDING SUNNY CORNER, ST. MORITZ BOB-RUN',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '93420c2344e54f3e139102b81a6599e6',
#   'text': '[Image\nunavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '3ab9b52b5232d803ee4ac94b231e1e04',
#   'text': 'Plate XXXI',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '646ff406e90515a67c415080f4ed4b1c',
#   'text': 'BOB-RUN, ST. MORITZ',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '93420c2344e54f3e139102b81a6599e6',
#   'text': '[Image\nunavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'fad1b3d2101aea63e17615c9758f1118',
#   'text': 'Plate XXXII',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '8b846f4e48a131715bfebb4bc8c8a0ae',
#   'text': 'THE STRAIGHT FROM THE BRIDGE, ST. MORITZ BOB-RUN',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '93420c2344e54f3e139102b81a6599e6',
#   'text': '[Image\nunavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '3c0b192438f6e5f39d5ec6beb59ea321',
#   'text': 'Plate XXXIII',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'd4a29ddfc75b7424ae0118f91b47a492',
#   'text': 'ST. MORITZ BOB-RUN',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'aa7aedebbe0d4e70e0d72d856e7dc321',
#   'text': 'CHAPTER\nV',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'dcea2070d3d9171c9c817967917ca77b',
#   'text': 'ICE-HOCKEY',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'e1b22c3e168288282d72f5c55043859e',
#   'text': '[Image unavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '8738b816c128ffcafa1fbfedd3be5f44',
#   'text': 'ICE HOCKEY',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '82622f4f7242980722d8586e89395ce2',
#   'text': 'From the Drawing by Fleming Williams',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '0c50ac0a7b8ea5086f383ad94916cc58',
#   'text': 'Rules of Match Play',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '72aab170908ec1a940822e9cfda5365b',
#   'text': 'CHAPTER\nVI',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '0354439dc766447e6406fdd882e8e918',
#   'text': 'SKI-ING',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'e1b22c3e168288282d72f5c55043859e',
#   'text': '[Image unavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'a1d35f74828430b5dfa84cd0108834af',
#   'text': 'THE TELEMARK TURN',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '82622f4f7242980722d8586e89395ce2',
#   'text': 'From the Drawing by Fleming Williams',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '8f0127c9545e76304e2bff54842155a7',
#   'text': 'Jumping',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'e1b22c3e168288282d72f5c55043859e',
#   'text': '[Image unavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'e989ba605b2be889ccd73fd116db01b0',
#   'text': 'THE JUMP',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
# ...
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '97c1289f9881a491ecce964401c61058',
#   'text': 'Plate XXXVII',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'fd6b523ac0c7006dc8dc3a2245f1c56a',
#   'text': 'SKI-JUMPING',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '93420c2344e54f3e139102b81a6599e6',
#   'text': '[Image\nunavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '043f071e8d6e727a08249140f53a6042',
#   'text': 'Plate XXXVIII',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '6963e66b8a4930cfbdcc6dd259cd8841',
#   'text': 'SKI-JUMPING, MONTANA, SWITZERLAND',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '93420c2344e54f3e139102b81a6599e6',
#   'text': '[Image\nunavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '990926be99c12e96c90a1bd24e1e3651',
#   'text': 'Plate XXXIX',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '3308d4dbf477fb33a71e682980282c53',
#   'text': 'VETERANS OF THE ST. MORITZ SKI CLUB',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '36fa85ade3da452c1db627d457da646b',
#   'text': 'CHAPTER\nVII',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '272ffcc12c87aef80e8c6d59aeb699b0',
#   'text': 'NOTES ON WINTER RESORTS',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'e6bbe113b2a5fee58912eba932378fa3',
#   'text': 'Oberland\nDistrict',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '93420c2344e54f3e139102b81a6599e6',
#   'text': '[Image\nunavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'f22f9c34e0b4299e8b1b19e750c5aa88',
#   'text': 'Plate XL',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '33505d7d84b48f73addc7fa0f3b50c53',
#   'text': 'A PRACTICE GROUND',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '93420c2344e54f3e139102b81a6599e6',
#   'text': '[Image\nunavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'e1818ad337b210914b3b18e4a25b3c70',
#   'text': 'Plate XLI',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '0ee2a9edd3beaac66f111a2c22235f3e',
#   'text': 'CROSSING THE ROAD ON THE CRESTA',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '93420c2344e54f3e139102b81a6599e6',
#   'text': '[Image\nunavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '216f045c506941fa29f6bbd6cf8fb703',
#   'text': 'Plate XLII',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '5f6bc4f294592d4e3105174baa2facac',
#   'text': 'TOP OF KLOSTERS RUN, DAVOS',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '93420c2344e54f3e139102b81a6599e6',
#   'text': '[Image\nunavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '728d836171c3c4121bf88e8046444d4b',
#   'text': 'Plate XLIII',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'bff0fccbb852980d6a0d5e2ec06ff0c8',
#   'text': 'THE START, SCHATZ ALP RUN, DAVOS',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '93420c2344e54f3e139102b81a6599e6',
#   'text': '[Image\nunavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'a76c94a1980de291a9d47d684bdfde0d',
#   'text': 'Plate XLIV',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '8110d58728cac1ec87ba63b4e4a3b6b0',
#   'text': 'BOBBING ON THE SCHATZ ALP RUN, DAVOS',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '93420c2344e54f3e139102b81a6599e6',
#   'text': '[Image\nunavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '18a90b7621fa2cda203f151e38c6757b',
#   'text': 'Plate XLV',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '2ccfff80cc91ab3ecc9e6ee39be79c06',
#   'text': 'SKATING-RINK AT VILLARS',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '93420c2344e54f3e139102b81a6599e6',
#   'text': '[Image\nunavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '7f687861a3f7a553603d2120911562b5',
#   'text': 'Plate XLVI',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '43677b8bc45e872f854630785b4369ad',
#   'text': 'AT LA BRETAYE, VILLARS',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '93420c2344e54f3e139102b81a6599e6',
#   'text': '[Image\nunavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'e3d9e3f82e287b3980bcd78cf94e626a',
#   'text': 'Plate XLVII',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'd0495ce71bdbe2d34698dc572e274208',
#   'text': 'CHAPTER\nVIII',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'bc0864682405480021aabbd2e39fb6c9',
#   'text': 'FOR PARENTS AND GUARDIANS',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'e1b22c3e168288282d72f5c55043859e',
#   'text': '[Image unavailable.]',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'fb306e3a2c4fcfcf1790d5c7b8c1a182',
#   'text': 'THE ICE CARNIVAL',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '82622f4f7242980722d8586e89395ce2',
#   'text': 'From the Drawing by Fleming Williams',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '97e5010f68f6c51ac20182e6c641041a',
#   'text': 'Ballantyne, Hanson &\nCo.',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '86a45cbeb57a7acfe6a453a2770366fa',
#   'text': 'at Paul’s Work, Edinburgh',
#   'metadata': {'page_number': 2,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '8c90518133a5f0db85bfa4fcfd13d59c',
#   'text': 'For particulars apply to the Publishers.',
#   'metadata': {'page_number': 3,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '4187557fe866bf9c00d31b0ec61fe83a',
#   'text': 'Recent Fine Art Books',
#   'metadata': {'page_number': 4,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '26154b815dff4b3caac765d4f816eab5',
#   'text': 'HANS HOLBEIN',
#   'metadata': {'page_number': 4,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'd36025f7ff51418df350da3da5fa032b',
#   'text': 'THE YOUNGER',
#   'metadata': {'page_number': 4,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'd9b4ebd1889546ca294e57b9c3dce089',
#   'text': 'By ARTHUR B. CHAMBERLAIN',
#   'metadata': {'page_number': 4,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'ea6fcc68d27d80f037b742ac30c13856',
#   'text': 'ASSISTANT KEEPER OF THE CORPORATION ART GALLERY,\nBIRMINGHAM',
#   'metadata': {'page_number': 4,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '4dd03a0e05dcc584eb1cdb77cb43d785',
#   'text': 'With 252 Illustrations, including 24 in Colour',
#   'metadata': {'page_number': 4,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'b5024d8150981e4bb8b9079a665caa57',
#   'text': 'Demy 4to. Two Volumes. Cloth, gilt top, £3, 3s.\nnet.',
#   'metadata': {'page_number': 4,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '4280fece8fd29da67892d26fbbd639df',
#   'text': 'HOMES AND HAUNTS OF RUSKIN',
#   'metadata': {'page_number': 5,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '2fd43b4ea25f4e74daf9a75ab9f72af7',
#   'text': 'By Sir EDWARD T. COOK',
#   'metadata': {'page_number': 5,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '2bdd59865186e0532c213df11bc331ef',
#   'text': 'THE LIFE OF THE BEE',
#   'metadata': {'page_number': 5,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '9d47c30d16eeb192d796862cbb515ae0',
#   'text': 'HOURS OF GLADNESS',
#   'metadata': {'page_number': 5,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'e6a2f7d4e5d2507b3963997a9cc1c101',
#   'text': 'EIGHT NATURE ESSAYS',
#   'metadata': {'page_number': 5,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '130d0eefcb350f1f0e87a93fdd7a15f3',
#   'text': 'LONDON: GEORGE ALLEN & CO., LIMITED',
#   'metadata': {'page_number': 5,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'e6930ea066dc100055baca3521e6b8b1',
#   'text': 'START: FULL LICENSE',
#   'metadata': {'page_number': 6,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '187501c54fa32e57366875d06f4fb737',
#   'text': 'THE FULL\nPROJECT GUTENBERG LICENSE',
#   'metadata': {'page_number': 6,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'd3ea10b13e085019b7e9f349683dfc6b',
#   'text': 'PLEASE READ THIS BEFORE YOU DISTRIBUTE OR USE THIS WORK',
#   'metadata': {'page_number': 6,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '471fcbd48a09bcef0008cfec05b36b2a',
#   'text': 'Section 1. General Terms of Use and Redistributing Project Gutenberg™\nelectronic works',
#   'metadata': {'page_number': 6,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': 'ac6f3bc8072da317ca9140b2bfa56533',
#   'text': 'Section 2. Information about the Mission of Project Gutenberg™',
#   'metadata': {'page_number': 6,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '02084f5715b457c0866b120d5d89959c',
#   'text': 'Section 3. Information about the Project Gutenberg Literary Archive\nFoundation',
#   'metadata': {'page_number': 6,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '3fc7af460165cbf738d34a2dc355291e',
#   'text': 'Section 4. Information about Donations to the Project Gutenberg Literary\nArchive Foundation',
#   'metadata': {'page_number': 6,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '51055211bb4994c62bb88c832f1aa7ae',
#   'text': 'www.gutenberg.org/donate.',
#   'metadata': {'page_number': 6,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '496828ca399919ead9af5f1e82141f7f',
#   'text': 'Section 5. General Information About Project Gutenberg™ electronic works',
#   'metadata': {'page_number': 6,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'Title',
#   'element_id': '1d59e0f7ef1034f07023aa35b0dc2731',
#   'text': 'www.gutenberg.org.',
#   'metadata': {'page_number': 6,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}}]

# %%
chapters = [
    "THE SUN-SEEKER",
    "RINKS AND SKATERS",
    "TEES AND CRAMPITS",
    "ICE-HOCKEY",
    "SKI-ING",
    "NOTES ON WINTER RESORTS",
    "FOR PARENTS AND GUARDIANS",
]

# %%
chapter_ids= {}
for element in res.elements:
    for chapter in chapters:
        if element['text'] == chapter and element['type'] == 'Title':
            chapter_ids[element['element_id']] = chapter
            break

# %%
chapter_ids
# Out:
# {'d9725192dcad4b316b9000b2e0b9d803': 'THE SUN-SEEKER',
#  '85a84e38543ad3417cdef25e3616cbbc': 'RINKS AND SKATERS',
#  '5229c64d88a2a9bd98581911deedc70c': 'TEES AND CRAMPITS',
#  'dcea2070d3d9171c9c817967917ca77b': 'ICE-HOCKEY',
#  '0354439dc766447e6406fdd882e8e918': 'SKI-ING',
#  '272ffcc12c87aef80e8c6d59aeb699b0': 'NOTES ON WINTER RESORTS',
#  'bc0864682405480021aabbd2e39fb6c9': 'FOR PARENTS AND GUARDIANS'}

# %%
chapter_to_id = {v:k for k,v in chapter_ids.items()}
chapter_to_id
# Out:
# {'THE SUN-SEEKER': 'd9725192dcad4b316b9000b2e0b9d803',
#  'RINKS AND SKATERS': '85a84e38543ad3417cdef25e3616cbbc',
#  'TEES AND CRAMPITS': '5229c64d88a2a9bd98581911deedc70c',
#  'ICE-HOCKEY': 'dcea2070d3d9171c9c817967917ca77b',
#  'SKI-ING': '0354439dc766447e6406fdd882e8e918',
#  'NOTES ON WINTER RESORTS': '272ffcc12c87aef80e8c6d59aeb699b0',
#  'FOR PARENTS AND GUARDIANS': 'bc0864682405480021aabbd2e39fb6c9'}

# %%
[x for x in res.elements if x["metadata"].get("parent_id") == chapter_to_id["ICE-HOCKEY"]][0]
# Out:
# {'type': 'NarrativeText',
#  'element_id': 'a4c8c73b30452b62425c99d1fe76425e',
#  'text': 'Many of the Swiss winter-resorts can put\ninto the field a very strong ice-hockey team, and fine teams from other\ncountries often make winter tours there; but the ice-hockey which the\nordinary winter visitor will be apt to join in will probably be of the\nmost elementary and unscientific kind indulged in, when the skating day\nis drawing to a close, by picked-up sides. As will be readily\nunderstood, the ice over which a hockey match has been played is\nperfectly useless for skaters any more that day until it has been swept,\nscraped, and sprinkled or flooded; and in consequence, at all Swiss\nresorts, with the exception of St. Moritz, where there is a rink that\nhas been made for the hockey-player, or when an important match is being\nplayed, this sport is supplementary to such others as I have spoken of.\nNobody, that is, plays hockey and nothing else, since he cannot play\nhockey at all till the greedy skaters have finished with the ice.',
#  'metadata': {'page_number': 2,
#   'languages': ['eng'],
#   'parent_id': 'dcea2070d3d9171c9c817967917ca77b',
#   'filename': 'winter-sports.epub',
#   'filetype': 'application/epub'}}

# %%
client = chromadb.PersistentClient(path="chroma_tmp",settings=chromadb.Settings(allow_reset=True))
client.reset()
# Out:
# INFO: Anonymized telemetry enabled. See https://docs.trychroma.com/telemetry for more information.
# True

# %%
collection = client.create_collection(
    name='winter_sports',
    metadata={"hnsw:space": "cosine"}
)

# %%
for element in res.elements:
    parent_id = element["metadata"].get("parent_id")
    chapter = chapter_ids.get(parent_id, "")
    collection.add(
        documents=[element["text"]],
        ids=[element["element_id"]],
        metadatas=[{"chapter": chapter}]
    )
# Out:
# /Users/praveenreddy/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz: 100%
# 2024-05-09 05:35:34.715095 [W:onnxruntime:, helper.cc:67 IsInputSupported] CoreML does not support input dim > 16384. Input:embeddings.word_embeddings.weight, shape: {30522,384}
# 2024-05-09 05:35:34.715694 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 49 number of nodes in the graph: 323 number of nodes supported by CoreML: 231
# WARNING: Insert of existing embedding ID: c16730e3ef4b7fd901346e355d7e11ac
# WARNING: Add of existing embedding ID: c16730e3ef4b7fd901346e355d7e11ac
# WARNING: Insert of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Add of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Insert of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Add of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Insert of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Add of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Insert of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Add of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Insert of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Add of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Insert of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Add of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Insert of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Add of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Insert of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Add of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Insert of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Add of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Insert of existing embedding ID: e1b22c3e168288282d72f5c55043859e
# WARNING: Add of existing embedding ID: e1b22c3e168288282d72f5c55043859e
# WARNING: Insert of existing embedding ID: 82622f4f7242980722d8586e89395ce2
# WARNING: Add of existing embedding ID: 82622f4f7242980722d8586e89395ce2
# WARNING: Insert of existing embedding ID: e1b22c3e168288282d72f5c55043859e
# WARNING: Add of existing embedding ID: e1b22c3e168288282d72f5c55043859e
# WARNING: Insert of existing embedding ID: 82622f4f7242980722d8586e89395ce2
# WARNING: Add of existing embedding ID: 82622f4f7242980722d8586e89395ce2
# WARNING: Insert of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Add of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Insert of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Add of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Insert of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Add of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Insert of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Add of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Insert of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Add of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Insert of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Add of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Insert of existing embedding ID: 5c0114a68e34a23e9411f13e3c48fb9b
# WARNING: Add of existing embedding ID: 5c0114a68e34a23e9411f13e3c48fb9b
# WARNING: Insert of existing embedding ID: 148b65833777b97f6433ce9a80e5c91d
# WARNING: Add of existing embedding ID: 148b65833777b97f6433ce9a80e5c91d
# WARNING: Insert of existing embedding ID: fe4d734fbbeaa0f14752a01bb2b3d572
# WARNING: Add of existing embedding ID: fe4d734fbbeaa0f14752a01bb2b3d572
# WARNING: Insert of existing embedding ID: 401bbfcccf562fbe3a88daf957e15a6b
# WARNING: Add of existing embedding ID: 401bbfcccf562fbe3a88daf957e15a6b
# WARNING: Insert of existing embedding ID: 8874cdae31218255177c28e02b38c299
# WARNING: Add of existing embedding ID: 8874cdae31218255177c28e02b38c299
# WARNING: Insert of existing embedding ID: 60ecd15fc0787beaf91d71fca986e345
# WARNING: Add of existing embedding ID: 60ecd15fc0787beaf91d71fca986e345
# WARNING: Insert of existing embedding ID: 76d24e43b89f60f92963c0546c2f6a51
# WARNING: Add of existing embedding ID: 76d24e43b89f60f92963c0546c2f6a51
# WARNING: Insert of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Add of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Insert of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Add of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Insert of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Add of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Insert of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Add of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Insert of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Add of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Insert of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Add of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Insert of existing embedding ID: e1b22c3e168288282d72f5c55043859e
# WARNING: Add of existing embedding ID: e1b22c3e168288282d72f5c55043859e
# WARNING: Insert of existing embedding ID: 82622f4f7242980722d8586e89395ce2
# WARNING: Add of existing embedding ID: 82622f4f7242980722d8586e89395ce2
# WARNING: Insert of existing embedding ID: c2b10dcbc1828df6080d9ea3cd9de6b6
# WARNING: Add of existing embedding ID: c2b10dcbc1828df6080d9ea3cd9de6b6
# WARNING: Insert of existing embedding ID: c2b10dcbc1828df6080d9ea3cd9de6b6
# WARNING: Add of existing embedding ID: c2b10dcbc1828df6080d9ea3cd9de6b6
# WARNING: Insert of existing embedding ID: c2b10dcbc1828df6080d9ea3cd9de6b6
# WARNING: Add of existing embedding ID: c2b10dcbc1828df6080d9ea3cd9de6b6
# WARNING: Insert of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Add of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Insert of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Add of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Insert of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Add of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Insert of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Add of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Insert of existing embedding ID: e1b22c3e168288282d72f5c55043859e
# WARNING: Add of existing embedding ID: e1b22c3e168288282d72f5c55043859e
# WARNING: Insert of existing embedding ID: 82622f4f7242980722d8586e89395ce2
# WARNING: Add of existing embedding ID: 82622f4f7242980722d8586e89395ce2
# WARNING: Insert of existing embedding ID: e1b22c3e168288282d72f5c55043859e
# WARNING: Add of existing embedding ID: e1b22c3e168288282d72f5c55043859e
# WARNING: Insert of existing embedding ID: 82622f4f7242980722d8586e89395ce2
# WARNING: Add of existing embedding ID: 82622f4f7242980722d8586e89395ce2
# WARNING: Insert of existing embedding ID: e1b22c3e168288282d72f5c55043859e
# WARNING: Add of existing embedding ID: e1b22c3e168288282d72f5c55043859e
# WARNING: Insert of existing embedding ID: 82622f4f7242980722d8586e89395ce2
# WARNING: Add of existing embedding ID: 82622f4f7242980722d8586e89395ce2
# WARNING: Insert of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Add of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Insert of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Add of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Insert of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Add of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Insert of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Add of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Insert of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Add of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Insert of existing embedding ID: 725c18943de7544b1b309e2bd6d9dca3
# WARNING: Add of existing embedding ID: 725c18943de7544b1b309e2bd6d9dca3
# WARNING: Insert of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Add of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Insert of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Add of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Insert of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Add of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Insert of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Add of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Insert of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Add of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Insert of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Add of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Insert of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Add of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Insert of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Add of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Insert of existing embedding ID: e1b22c3e168288282d72f5c55043859e
# WARNING: Add of existing embedding ID: e1b22c3e168288282d72f5c55043859e
# WARNING: Insert of existing embedding ID: 82622f4f7242980722d8586e89395ce2
# WARNING: Add of existing embedding ID: 82622f4f7242980722d8586e89395ce2
# WARNING: Insert of existing embedding ID: e1b22c3e168288282d72f5c55043859e
# WARNING: Add of existing embedding ID: e1b22c3e168288282d72f5c55043859e
# WARNING: Insert of existing embedding ID: 82622f4f7242980722d8586e89395ce2
# WARNING: Add of existing embedding ID: 82622f4f7242980722d8586e89395ce2
# WARNING: Insert of existing embedding ID: e1b22c3e168288282d72f5c55043859e
# WARNING: Add of existing embedding ID: e1b22c3e168288282d72f5c55043859e
# WARNING: Insert of existing embedding ID: 82622f4f7242980722d8586e89395ce2
# WARNING: Add of existing embedding ID: 82622f4f7242980722d8586e89395ce2
# WARNING: Insert of existing embedding ID: e1b22c3e168288282d72f5c55043859e
# WARNING: Add of existing embedding ID: e1b22c3e168288282d72f5c55043859e
# WARNING: Insert of existing embedding ID: 82622f4f7242980722d8586e89395ce2
# WARNING: Add of existing embedding ID: 82622f4f7242980722d8586e89395ce2
# WARNING: Insert of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Add of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Insert of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Add of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Insert of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Add of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Insert of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Add of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Insert of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Add of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Insert of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Add of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Insert of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Add of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Insert of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Add of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Insert of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Add of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Insert of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Add of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Insert of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Add of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Insert of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Add of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Insert of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Add of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Insert of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Add of existing embedding ID: 93420c2344e54f3e139102b81a6599e6
# WARNING: Insert of existing embedding ID: e1b22c3e168288282d72f5c55043859e
# WARNING: Add of existing embedding ID: e1b22c3e168288282d72f5c55043859e
# WARNING: Insert of existing embedding ID: 82622f4f7242980722d8586e89395ce2
# WARNING: Add of existing embedding ID: 82622f4f7242980722d8586e89395ce2
# WARNING: Insert of existing embedding ID: c16730e3ef4b7fd901346e355d7e11ac
# WARNING: Add of existing embedding ID: c16730e3ef4b7fd901346e355d7e11ac

# %%
results = collection.peek()
print(results["documents"])
# Out:
# ['The Project Gutenberg eBook of Winter Sports in\nSwitzerland, by E. F. Benson', '\nThis ebook is for the use of anyone anywhere in the United States and\nmost other parts of the world at no cost and with almost no restrictions\nwhatsoever. You may copy it, give it away or re-use it under the terms\nof the Project Gutenberg License included with this ebook or online at\n', 'www.gutenberg.org. If you are not located\nin the United States, you’ll have to check the laws of the country where\nyou are located before using this eBook.', 'Title: Winter Sports in Switzerland', 'Author: E. F. Benson', 'Illustrator: C. Fleming Williams', 'Photographer: Mrs. Aubrey Le Blond', 'Release date: August 23, 2019 [EBook #60153]', 'Most recently updated: January 30, 2020', 'Language: English']

# %%
result = collection.query(
    query_texts = ['how many plahyers are on team'],
    n_results=2,
    where={'chapter':'ICE-HOCKEY'}
)
print(json.dumps(result))
# Out:
# {"ids": [["392b0250af6c3b3a472b9bba6c9fc813", "3c94727f6879fb85fc32d0c1b2eb5b32"]], "distances": [[0.6144973635673523, 0.8437265157699585]], "metadatas": [[{"chapter": "ICE-HOCKEY"}, {"chapter": "ICE-HOCKEY"}]], "embeddings": null, "documents": [["It is a wonderful and delightful sight to watch the speed and\naccuracy of a first-rate team, each member of which knows the play of\nthe other five players. The finer the team, as is always the case, the\ngreater is their interdependence on each other, and the less there is of\nindividual play. Brilliant running and dribbling, indeed, you will see;\nbut as distinguished from a side composed of individuals, however good,\nwho are yet not a team, these brilliant episodes are always part of a\nplan, and end not in some wild shot but in a pass or a succession of\npasses, designed to lead to a good opening for scoring. There is,\nindeed, no game at which team play outwits individual brilliance so\ncompletely.", "For the rest, everybody knows the \u201csort of thing\u201d hockey is, and\nquite rightly supposes that ice-hockey is the same \u201csort of thing\u201d\nplayed on a field of ice by performers shod in skates. As is natural,\nthe practice and ability which enable a man to play ordinary hockey with\nmoderate success are a large factor in his success when he woos the more\nelusive sister-sport; another factor, and one which is not sufficiently\nappreciated, is the strength of his skating. It is not enough to be able\nto run very swiftly on the skates: no one is an ice-hockey player of the\nlowest grade who cannot turn quickly to right or left, start quickly,\nand above all, stop quickly. However swift a player may be, he is\npractically useless to his side unless he can, with moderate suddenness,\ncheck his headlong career, turn quickly, and when the time comes again\nstart quickly."]]}
